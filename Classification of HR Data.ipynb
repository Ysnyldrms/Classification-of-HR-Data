# %%
import pandas as pd 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("hr_data.csv")

# %% [markdown]
# ### EDA - Exploratory Data Analysis

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        2  ...            80                 0
# ...

# %%
df.sample(2)
# Out:
#      Age BusinessTravel  DailyRate              Department  DistanceFromHome  \
# 690   31  Travel_Rarely        616  Research & Development                12
# 182   41  Travel_Rarely       1356                   Sales                20
#
#      Education EducationField  EmployeeCount  EmployeeNumber  \
# 690          3        Medical              1             961
# 182          2      Marketing              1             248
#
#      EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 690                        4  ...            80                 2
# 182                        2  ...            80                 0
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 690                 10                      2               1               9
# 182                  4                      5               2               4
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                           0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
sns.heatmap(df.corr(), annot = True)
sns.set(rc={'figure.figsize':(20, 15)})

# %% [markdown]
# #####  If correlation between two column is bigger than %90, this means this columns has repated values. When we look at the data we can see some of them comlpetely same.

# %%
df.drop(["StandardHours", "EmployeeCount", "JobLevel"], axis = 1 , inplace = True)

# %% [markdown]
# ##### Let's look again the heatmap

# %%
sns.heatmap(df.corr(), annot = True)
sns.set(rc={'figure.figsize':(20, 15)})

# %%
df
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                    1          2  Life Sciences               1
# ...

# %%
df.shape
# Out:
# (1470, 32)

# %%
df.columns              # Column names
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
df["Attrition"].value_counts()            # there are 1020 people who don't leave the job
# Out:
# No     1020
# Yes     185
# Name: Attrition, dtype: int64

# %%
df.isnull().sum()                  # 265 value is null. We will predict this columns
# Out:
# Age                           0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 0
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StockOptionLevel              0
# TotalWorkingYears             0
# TrainingTimesLastYear         0
# WorkLifeBalance               0
# YearsAtCompany                0
# YearsInCurrentRole            0
# ...

# %%
df["Attrition"] = df["Attrition"].replace(["Yes","No"],[1,0])        # Find Attrition and change with 0 and 1

# %%
null = df[df["Attrition"].isnull()]

# %%
notnull = df[df["Attrition"].notnull()]

# %%
null.shape
# Out:
# (265, 32)

# %%
notnull.shape
# Out:
# (1205, 32)

# %%
df
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                    1          2  Life Sciences               1
# ...

# %%
x = notnull.drop("Attrition", axis = 1)      
y = notnull["Attrition"]

# %%
x
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1439   36      Travel_Rarely        557                   Sales
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                    1          2  Life Sciences               1
# ...

# %%
df["Department"].unique()           # to see departments
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df["EducationField"].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %% [markdown]
# ### Modelling

# %%
x = pd.get_dummies(x,drop_first = True)

# %%
x
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeNumber  \
# 0      41       1102                 1          2               1
# 1      49        279                 8          1               2
# 2      37       1373                 2          2               4
# 3      33       1392                 3          4               5
# 4      27        591                 2          1               7
# ...   ...        ...               ...        ...             ...
# 1439   36        557                 3          3            2024
# 1466   39        613                 6          1            2062
# 1467   27        155                 4          3            2064
# 1468   49       1023                 2          3            2065
# 1469   34        628                 8          3            2068
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobSatisfaction  \
# 0                           2          94               3                4
# ...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
g = GaussianNB()
b = BernoulliNB()

# %%
g.fit(x,y)                 # model trained
# Out:
# GaussianNB()

# %%
b.fit(x,y)
# Out:
# BernoulliNB()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
tahmin1 = g.predict(x)
tahmin2 = b.predict(x)

# %%
accuracy_score(tahmin1,y)
# Out:
# 0.816597510373444

# %%
accuracy_score(tahmin2,y)
# Out:
# 0.8448132780082988

# %%
precision_score(tahmin2,y)
# Out:
# 0.3027027027027027

# %%
confusion_matrix(tahmin2,y)                 # (True Positive, False Negative, False Positive, True Negative)
# Out:
# array([[962, 129],
#        [ 58,  56]], dtype=int64)

# %%
confusion_matrix(tahmin1,y)
# Out:
# array([[866,  67],
#        [154, 118]], dtype=int64)

# %%
print(classification_report(tahmin1,y))               # see as a report
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.93      0.89       933
#          1.0       0.64      0.43      0.52       272
#
#     accuracy                           0.82      1205
#    macro avg       0.74      0.68      0.70      1205
# weighted avg       0.80      0.82      0.80      1205

# %%
print(classification_report(tahmin2,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.88      0.91      1091
#          1.0       0.30      0.49      0.37       114
#
#     accuracy                           0.84      1205
#    macro avg       0.62      0.69      0.64      1205
# weighted avg       0.88      0.84      0.86      1205

# %%
from sklearn.neighbors import KNeighborsClassifier          # K-Neighbors method
k =  KNeighborsClassifier()

# %%
k.fit(x,y)
# Out:
# KNeighborsClassifier()

# %%
tahmin3 = k.predict(x)

# %%
print(classification_report(tahmin3,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.86      0.92      1162
#          1.0       0.15      0.63      0.24        43
#
#     accuracy                           0.86      1205
#    macro avg       0.57      0.75      0.58      1205
# weighted avg       0.95      0.86      0.90      1205

# %%
confusion_matrix(tahmin3,y)
# Out:
# array([[1004,  158],
#        [  16,   27]], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression      
l = LogisticRegression()

# %%
l.fit(x,y)
# Out:
# LogisticRegression()

# %%
tahmin4 = l.predict(x)

# %%
print(classification_report(tahmin4,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.85      0.92      1201
#          1.0       0.02      0.75      0.03         4
#
#     accuracy                           0.85      1205
#    macro avg       0.51      0.80      0.47      1205
# weighted avg       1.00      0.85      0.91      1205

# %%
confusion_matrix(tahmin4,y)
# Out:
# array([[1019,  182],
#        [   1,    3]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
d = DecisionTreeClassifier()

# %%
d.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
tahmin5 = d.predict(x)

# %%
confusion_matrix(tahmin5,y)
# Out:
# array([[1020,    0],
#        [   0,  185]], dtype=int64)

# %%
print(classification_report(tahmin5,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1020
#          1.0       1.00      1.00      1.00       185
#
#     accuracy                           1.00      1205
#    macro avg       1.00      1.00      1.00      1205
# weighted avg       1.00      1.00      1.00      1205

# %%
from sklearn.ensemble import RandomForestClassifier
r = RandomForestClassifier()

# %%
r.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
tahmin6 = r.predict(x)

# %%
confusion_matrix(tahmin6,y)
# Out:
# array([[1020,    0],
#        [   0,  185]], dtype=int64)

# %%
print(classification_report(tahmin6,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      1020
#          1.0       1.00      1.00      1.00       185
#
#     accuracy                           1.00      1205
#    macro avg       1.00      1.00      1.00      1205
# weighted avg       1.00      1.00      1.00      1205

# %%
from sklearn.ensemble import GradientBoostingClassifier
gr = GradientBoostingClassifier()

# %%
gr.fit(x,y)
# Out:
# GradientBoostingClassifier()

# %%
tahmin7 = gr.predict(x)

# %%
confusion_matrix(tahmin7,y)
# Out:
# array([[1019,   53],
#        [   1,  132]], dtype=int64)

# %%
print(classification_report(tahmin7,y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97      1072
#          1.0       0.71      0.99      0.83       133
#
#     accuracy                           0.96      1205
#    macro avg       0.86      0.97      0.90      1205
# weighted avg       0.97      0.96      0.96      1205

# %% [markdown]
# #### Let's create a dataset and predict the result

# %%
data = [[24, 1, 855, 2, 2, 4, 3, 1, 44, 2, 1, 92, 2, 2, 3, 1, 5130.0000, 16632, 4, 0, 1, 0, 1, 0, 0, 0, 0, 0, 0, 0, 13, 3, 2, 80, 0, 9, 3, 4, 2, 7, 2, 4, 5]]

# %%
data_new = gr.predict(data)

# %%
data_new
# Out:
# array([1.])

# %% [markdown]
# ##### the answer is "yes"
